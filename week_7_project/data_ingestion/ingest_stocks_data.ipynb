# %%
import opendatasets as od

# %%
# !chmod 600 /Users/wilson/.kaggle/kaggle.json
# !kaggle datasets list
# Out:
# ref                                                             title                                             size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  -----------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# meirnizri/covid19-dataset                                       COVID-19 Dataset                                   5MB  2022-11-13 15:47:17          10299        307  1.0
# michals22/coffee-dataset                                        Coffee dataset                                    24KB  2022-12-15 20:02:12           1507         47  1.0
# thedevastator/jobs-dataset-from-glassdoor                       Salary Prediction                                  3MB  2022-11-16 13:52:31           6492        146  1.0
# ...

# %%
# !kaggle datasets download -d paultimothymooney/stock-market-data
# Out:
# stock-market-data.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
from zipfile import ZipFile
zf = ZipFile('stock-market-data.zip', 'r')
zf.extractall('data/stocks/csv')
zf.close()

# %%
# !cp -r data/stocks/csv/stock_market_data/* data/stocks/csv/

# %%
# !rm -rf data/stocks/csv/stock_market_data

# %%
# !rm -rf data/stocks/csv/stock_market_data

# %%
# Upload Nasdaq
# !gcloud storage cp data/stocks/csv/nasdaq/csv gs://de_zoomcamp_project_us/raw/stocks/nasdaq -r
# Out:
# Copying file://data/stocks/csv/nasdaq/csv/CSCO.csv to gs://de_zoomcamp_project_us/raw/stocks/nasdaq/csv/CSCO.csv
# Copying file://data/stocks/csv/nasdaq/csv/BIOS.csv to gs://de_zoomcamp_project_us/raw/stocks/nasdaq/csv/BIOS.csv
# Copying file://data/stocks/csv/nasdaq/csv/CSBK.csv to gs://de_zoomcamp_project_us/raw/stocks/nasdaq/csv/CSBK.csv
# Copying file://data/stocks/csv/nasdaq/csv/SBGI.csv to gs://de_zoomcamp_project_us/raw/stocks/nasdaq/csv/SBGI.csv
# Copying file://data/stocks/csv/nasdaq/csv/UFCS.csv to gs://de_zoomcamp_project_us/raw/stocks/nasdaq/csv/UFCS.csv
# Copying file://data/stocks/csv/nasdaq/csv/AIRT.csv to gs://de_zoomcamp_project_us/raw/stocks/nasdaq/csv/AIRT.csv
# Copying file://data/stocks/csv/nasdaq/csv/ISSC.csv to gs://de_zoomcamp_project_us/raw/stocks/nasdaq/csv/ISSC.csv
# Copying file://data/stocks/csv/nasdaq/csv/KNDI.csv to gs://de_zoomcamp_project_us/raw/stocks/nasdaq/csv/KNDI.csv
# ...

# %%
# Upload sp500
# !gcloud storage cp data/stocks/csv/sp500/csv gs://de_zoomcamp_project_us/raw/stocks/sp500 -r
# Out:
# Copying file://data/stocks/csv/stock_market_data/sp500/csv/CSCO.csv to gs://de_zoomcamp_project_us/raw/stocks/sp500/csv/CSCO.csv
# Copying file://data/stocks/csv/stock_market_data/sp500/csv/UAL.csv to gs://de_zoomcamp_project_us/raw/stocks/sp500/csv/UAL.csv
# Copying file://data/stocks/csv/stock_market_data/sp500/csv/TROW.csv to gs://de_zoomcamp_project_us/raw/stocks/sp500/csv/TROW.csv
# Copying file://data/stocks/csv/stock_market_data/sp500/csv/ISRG.csv to gs://de_zoomcamp_project_us/raw/stocks/sp500/csv/ISRG.csv
# Copying file://data/stocks/csv/stock_market_data/sp500/csv/NVR.csv to gs://de_zoomcamp_project_us/raw/stocks/sp500/csv/NVR.csv
# Copying file://data/stocks/csv/stock_market_data/sp500/csv/MRO.csv to gs://de_zoomcamp_project_us/raw/stocks/sp500/csv/MRO.csv
# Copying file://data/stocks/csv/stock_market_data/sp500/csv/BA.csv to gs://de_zoomcamp_project_us/raw/stocks/sp500/csv/BA.csv
# ...

# %%
# !rm stock-market-data.zip
