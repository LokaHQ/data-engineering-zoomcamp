# %% [markdown]
# # Main

# %% [markdown]
# ## Data Lake

# %%
# Ingest Twitter data
# %run ingest_twitter_raw_data.ipynb
# Out:
# ref                                                             title                                             size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  -----------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# meirnizri/covid19-dataset                                       COVID-19 Dataset                                   5MB  2022-11-13 15:47:17          10287        307  1.0
# michals22/coffee-dataset                                        Coffee dataset                                    24KB  2022-12-15 20:02:12           1506         47  1.0
# thedevastator/jobs-dataset-from-glassdoor                       Salary Prediction                                  3MB  2022-11-16 13:52:31           6489        146  1.0
# ...

# %%
# Ingest Stocks data
# %run ingest_stocks_data.ipynb
# Out:
# ref                                                             title                                             size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  -----------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# meirnizri/covid19-dataset                                       COVID-19 Dataset                                   5MB  2022-11-13 15:47:17          10476        309  1.0
# michals22/coffee-dataset                                        Coffee dataset                                    24KB  2022-12-15 20:02:12           1576         48  1.0
# thedevastator/jobs-dataset-from-glassdoor                       Salary Prediction                                  3MB  2022-11-16 13:52:31           6568        148  1.0
# ...

# %% [markdown]
# # Data Warehouse

# %%
# Twitter Warehouse
# %run twitter_data_warehouse.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33850 entries, 0 to 33849
# Data columns (total 44 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       30735 non-null  float64
#  1   id               33850 non-null  int64
#  2   conversation_id  33850 non-null  int64
#  3   created_at       33850 non-null  object
#  4   date             33850 non-null  object
#  5   timezone         33850 non-null  int64
#  6   place            0 non-null      float64
#  7   tweet            33850 non-null  object
#  8   language         33850 non-null  object
#  9   hashtags         33850 non-null  object
#  10  cashtags         33850 non-null  object
#  11  user_id          33850 non-null  int64
#  12  user_id_str      30735 non-null  float64
#  13  username         33850 non-null  object
#  14  name             33850 non-null  object
#  15  day              30735 non-null  float64
# ...

# %%
# Stocks Warehouse
# %run stocks_data_warehouse.ipynb
# Out:
# /var/folders/t6/71hhy6450kl761gwrq_2xwf80000gn/T/ipykernel_20851/2945788399.py:7: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   stock['Date'] = pd.to_datetime(stock['Date'])
# /var/folders/t6/71hhy6450kl761gwrq_2xwf80000gn/T/ipykernel_20851/2945788399.py:7: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   stock['Date'] = pd.to_datetime(stock['Date'])
# /var/folders/t6/71hhy6450kl761gwrq_2xwf80000gn/T/ipykernel_20851/2945788399.py:7: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   stock['Date'] = pd.to_datetime(stock['Date'])
# ...
